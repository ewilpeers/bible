# %% [markdown]
# # init data

# %% [markdown]
# ## datasets

# %%
import pandas as pd
l65_df = pd.read_csv("RT65_words.csv", dtype={'strong_num': str})
hb_df = pd.read_csv("biblehub_hb_en_direct.csv", dtype={'strong_num': str})
strongs_df = pd.read_csv("greek-enh-lxx-apo-OT-blb.csv", dtype={'strong_num': str})
l65_g = l65_df.groupby(["book", "chapter", "verse"])
hb_g = hb_df.groupby(["book", "chapter", "verse"])
strongs_g = strongs_df.groupby(["book", "chapter", "verse"])
# Out:
# /tmp/ipykernel_4007180/4032689819.py:4: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   strongs_df = pd.read_csv("greek-enh-lxx-apo-OT-blb.csv", dtype={'strong_num': str})

# %% [markdown]
# ## verse mapping

# %%
# lv vietturis : ebreju vietturis
l65_to_hb={
('1_chronicles', 5, 27) : ('1_chronicles', 6, 1),
('1_chronicles', 5, 28) : ('1_chronicles', 6, 2),
('1_chronicles', 5, 29) : ('1_chronicles', 6, 3),
('1_chronicles', 5, 30) : ('1_chronicles', 6, 4),
('1_chronicles', 5, 31) : ('1_chronicles', 6, 5),
('1_chronicles', 5, 32) : ('1_chronicles', 6, 6),
('1_chronicles', 5, 33) : ('1_chronicles', 6, 7),
('1_chronicles', 5, 34) : ('1_chronicles', 6, 8),
('1_chronicles', 5, 35) : ('1_chronicles', 6, 9),
('1_chronicles', 5, 36) : ('1_chronicles', 6, 10),
('1_chronicles', 5, 37) : ('1_chronicles', 6, 11),
('1_chronicles', 5, 38) : ('1_chronicles', 6, 12),
('1_chronicles', 5, 39) : ('1_chronicles', 6, 13),
('1_chronicles', 5, 40) : ('1_chronicles', 6, 14),
('1_chronicles', 5, 41) : ('1_chronicles', 6, 15)
}
for i in range(1, 66+1):
    l65_to_hb[('1_chronicles', 6, i)]=('1_chronicles', 6, i+15)

for l, h in zip(range(1, 14+1), range(21, 34+1)):
    l65_to_hb[('1_kings', 5, l)]=('1_kings', 4, h)

for i in range(15, 32+1):
    l65_to_hb[('1_kings', 5, i)]=('1_kings', 5, i-14)



#merge 43 + 44
l65_to_hb_merge = {
    (('1_kings', 22, 43), ('1_kings', 22, 44)): ('1_kings', 22, 43)
}

#now update mapping
for i in range(43, 53+1):
    l65_to_hb[('1_kings', 22, i+1)]=('1_kings', 22, i)
#1 samuel 20:42+
l65_to_hb[('1_samuel', 20, 43)]=('1_samuel', 21, 1)
for i in range(1, 13+1):
    l65_to_hb[('1_samuel', 21, i)]=('1_samuel', 21, i+1)
#14, 15 merged => 14 hebrw
l65_to_hb_merge[(('1_samuel', 21, 14), ('1_samuel', 21, 15))] = ('1_samuel', 21, 15)

#1 samuel 23:28+
l65_to_hb[('1_samuel', 24, 1)] = ('1_samuel', 23, 29)
for i in range(2, 23+1):
    l65_to_hb[('1_samuel', 24, i)]=('1_samuel', 24, i-1)

#2chronicles 2:1
l65_to_hb[('2_chronicles', 1, 18)] = ('2_chronicles', 2, 1)
for i in range(1, 17+1):
    l65_to_hb[('2_chronicles', 2, i)]=('2_chronicles', 2, i+1)

#2chronicles 14:1
l65_to_hb[('2_chronicles', 13, 23)] = ('2_chronicles', 14, 1)
for i in range(1, 14+1):
    l65_to_hb[('2_chronicles', 14, i)]=('2_chronicles', 14, i+1)

#2kings 12:1-21
l65_to_hb[('2_kings', 12, 1)] = ('2_kings', 11, 21)
for i in range(2, 22+1):
    l65_to_hb[('2_kings', 12, i)]=('2_kings', 12, i-1)

#2 sam 18:33
l65_to_hb[('2_samuel', 19, 1)] = ('2_samuel', 18, 33)
for i in range(2, 44+1):
    l65_to_hb[('2_samuel', 19, i)]=('2_samuel', 19, i-1)

#daniel 3
l65_to_hb[('daniel', 3, 31)] = ('daniel', 4, 1)
#obsolote, now merge ir rghtfully updating the map.l65_to_hb[('daniel', 3, 32)] = ('daniel', 4, 2), 3

#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1 O T R Ā D I !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 1 lv verse = 2x heb verses, TODO: SPLIT THEM ON WORD BEING LAST IN 1st part
l65_to_hb_merge[(('daniel', 3, 32), "darījis")] = (('daniel', 4, 2), ('daniel', 4, 3))
for i in range(1, 34+1):
    l65_to_hb[('daniel', 4, i)] = ('daniel', 4, i+3)

#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1 O T R Ā D I !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 1 lv verse = 2x heb verses, TODO: SPLIT THEM ON WORD BEING LAST IN 1st part
l65_to_hb_merge[(('daniel', 5, 30), "nogalināts")] = (('daniel', 5, 30), ('daniel', 5, 31))

l65_to_hb[('deuteronomy', 13, 1)] = ('deuteronomy', 12, 32)
for i in range(2, 19+1):
    l65_to_hb[('deuteronomy', 13, i)]=('deuteronomy', 13, i-1)

l65_to_hb[('deuteronomy', 23, 1)] = ('deuteronomy', 22, 30)
for i in range(2, 26+1):
    l65_to_hb[('deuteronomy', 23, i)]=('deuteronomy', 23, i-1)

l65_to_hb[('deuteronomy', 28, 69)] = ('deuteronomy', 29, 1)
l65_to_hb_merge[(('deuteronomy', 29, 1), ('deuteronomy', 29, 2))]=('deuteronomy', 29, 2)

#ecclesiates
l65_to_hb[('ecclesiastes', 4, 17)] = ('ecclesiastes', 5, 1)
for i in range(1, 19+1):
    l65_to_hb[('ecclesiastes', 5, i)]=('ecclesiastes', 5, i+1)

l65_to_hb[('exodus', 1, 21)] = ('exodus', 1, 22)

l65_to_hb[('exodus', 7, 26)] = ('exodus', 8, 1)
l65_to_hb[('exodus', 7, 27)] = ('exodus', 8, 2)
l65_to_hb[('exodus', 7, 28)] = ('exodus', 8, 3)
l65_to_hb[('exodus', 7, 29)] = ('exodus', 8, 4)
for i in range(1, 28+1):
    l65_to_hb[('exodus', 8, i)]=('exodus', 8, i+4)

l65_to_hb[('exodus', 21, 37)] = ('exodus', 22, 1)
for i in range(1, 30+1):
    l65_to_hb[('exodus', 22, i)]=('exodus', 22, i+1)
#ezekiel
for i in range(45, 49+1):
    l65_to_hb[('ezekiel', 21, i-44)]=('ezekiel', 20, i)
for i in range(6, 37+1):
    l65_to_hb[('ezekiel', 21, i)]=('ezekiel', 21, i-5)

# genesis 3 panti savienoti vienā un izlaista 1 tauta
l65_to_hb_merge[(('genesis', 15, 19), "kadmoniešus", "refajiešus")] = (('genesis', 15, 19), ('genesis', 15, 20), ('genesis', 15, 21))

l65_to_hb_merge[(('genesis', 24, 65),('genesis', 24, 66))] = ('genesis', 24, 65)
for i in range(67, 68+1):
    l65_to_hb[('genesis', 24, i)]=('genesis', 24, i-1)

l65_to_hb[('genesis', 32, 1)]=('genesis', 31, 55)
for i in range(2, 33+1):
    l65_to_hb[('genesis', 32, i)]=('genesis', 32, i-1)

#hosea 1
l65_to_hb[('hosea', 2, 1)] = ('hosea', 1, 10)
l65_to_hb[('hosea', 2, 2)] = ('hosea', 1, 11)
for i in range(3, 25+1):
    l65_to_hb[('hosea', 2, i)]=('hosea', 2, i-2)

l65_to_hb[('hosea', 12, 1)] = ('hosea', 11, 12)
for i in range(2, 15+1):
    l65_to_hb[('hosea', 12, i)]=('hosea', 12, i-1)

l65_to_hb[('hosea', 14, 1)] =('hosea', 13, 16)
for i in range(2, 10+1):
    l65_to_hb[('hosea', 14, i)]=('hosea', 14, i-1)

#isaiah
l65_to_hb[('isaiah', 8, 23)] = ('isaiah', 9, 1)
for i in range(1, 20+1):
    l65_to_hb[('isaiah', 9, i)]=('isaiah', 9, i+1)

l65_to_hb[('jeremiah', 8, 23)] = ('jeremiah', 9, 1)
for i in range(1, 25+1):
    l65_to_hb[('jeremiah', 9, i)]=('jeremiah', 9, i+1)

# job
for i in range(25, 32+1):
    l65_to_hb[('job', 40, i)]=('job', 41, i-24)
for i in range(1, 26+1):
    l65_to_hb[('job', 41, i)]=('job', 41, i+8)
#joel
for i in range(1, 5+1):
    l65_to_hb[('joel', 3, i)]=('joel', 2, i+27)
for i in range(1, 21+1):
    l65_to_hb[('joel', 4, i)]=('joel', 3, i)

#jonah
l65_to_hb[('jonah', 2, 1)] = ('jonah', 1, 17)
for i in range(2, 11+1):
    l65_to_hb[('jonah', 2, i)]=('jonah', 2, i-1)

#leviticus
for i in range(20, 26+1):
    l65_to_hb[('leviticus', 5, i)]=('leviticus', 6, i-19)
for i in range(1, 23+1):
    l65_to_hb[('leviticus', 6, i)]=('leviticus', 6, i+7)

#malachi
for i in range(19, 24+1):
    l65_to_hb[('malachi', 3, i)]=('malachi', 4, i-18)
#malachi 4 in Latvian does not exist!!

#micah
l65_to_hb[('micah', 4, 14)] = ('micah', 5, 1)
for i in range(1, 14+1):
    l65_to_hb[('micah', 5, i)]=('micah', 5, i+1)

#nahum
l65_to_hb[('nahum', 2, 1)] = ('nahum', 1, 15)
for i in range(2, 14+1):
    l65_to_hb[('nahum', 2, i)]=('nahum', 2, i-1)

#nehemiah
l65_to_hb[('nehemiah', 10, 1)] = ('nehemiah', 9, 38)
for i in range(2, 40+1):
    l65_to_hb[('nehemiah', 10, i)]=('nehemiah', 10, i-1)


#numbers
for i in range(36, 50+1):
    l65_to_hb[('numbers', 17, i-35)]=('numbers', 16, i)
for i in range(16, 28+1):
    l65_to_hb[('numbers', 17, i)]=('numbers', 17, i-15)

l65_to_hb[('numbers', 30, 1)] = ('numbers', 29, 40)
for i in range(2, 17+1):
    l65_to_hb[('numbers', 30, i)]=('numbers', 30, i-1)

#psalms
def add_psalms_merging_verse_1_in_1965(chap, maxverse):
    l65_to_hb_merge[(('psalms', chap, 1),('psalms', chap, 2))] = ('psalms', chap, 1)
    for i in range(3, maxverse+1):
        l65_to_hb[('psalms', chap, i)]=('psalms', chap, i-1)
        
add_psalms_merging_verse_1_in_1965(3, 9)
add_psalms_merging_verse_1_in_1965(4, 9)
add_psalms_merging_verse_1_in_1965(5, 13)
add_psalms_merging_verse_1_in_1965(6, 11)
add_psalms_merging_verse_1_in_1965(7, 18)
add_psalms_merging_verse_1_in_1965(8, 10)
add_psalms_merging_verse_1_in_1965(9, 21)
add_psalms_merging_verse_1_in_1965(11, 8)
add_psalms_merging_verse_1_in_1965(12, 9)
add_psalms_merging_verse_1_in_1965(13, 7)
add_psalms_merging_verse_1_in_1965(18, 51)
add_psalms_merging_verse_1_in_1965(19, 15)
add_psalms_merging_verse_1_in_1965(20, 10)
add_psalms_merging_verse_1_in_1965(21, 14)
add_psalms_merging_verse_1_in_1965(22, 32)
add_psalms_merging_verse_1_in_1965(30, 13)
#so far ok, therefore will leave the rest of psalms as is no check
add_psalms_merging_verse_1_in_1965(31, 25)
add_psalms_merging_verse_1_in_1965(34, 23)
add_psalms_merging_verse_1_in_1965(36, 13)
add_psalms_merging_verse_1_in_1965(38, 23)
add_psalms_merging_verse_1_in_1965(39, 14)
add_psalms_merging_verse_1_in_1965(40, 18)
add_psalms_merging_verse_1_in_1965(41, 14)
add_psalms_merging_verse_1_in_1965(42, 12)
add_psalms_merging_verse_1_in_1965(44, 27)
add_psalms_merging_verse_1_in_1965(45, 18)
add_psalms_merging_verse_1_in_1965(46, 12)
add_psalms_merging_verse_1_in_1965(47, 10)
add_psalms_merging_verse_1_in_1965(48, 15)
add_psalms_merging_verse_1_in_1965(49, 21)
add_psalms_merging_verse_1_in_1965(51, 20)
add_psalms_merging_verse_1_in_1965(51, 21)
add_psalms_merging_verse_1_in_1965(52, 10)
add_psalms_merging_verse_1_in_1965(52, 11)
add_psalms_merging_verse_1_in_1965(53, 7)
add_psalms_merging_verse_1_in_1965(54, 8)
add_psalms_merging_verse_1_in_1965(54, 9)
add_psalms_merging_verse_1_in_1965(55, 24)
add_psalms_merging_verse_1_in_1965(56, 14)
add_psalms_merging_verse_1_in_1965(57, 12)
add_psalms_merging_verse_1_in_1965(58, 12)
add_psalms_merging_verse_1_in_1965(59, 18)
add_psalms_merging_verse_1_in_1965(60, 13)
add_psalms_merging_verse_1_in_1965(60, 14)
add_psalms_merging_verse_1_in_1965(61, 9)
add_psalms_merging_verse_1_in_1965(62, 13)
add_psalms_merging_verse_1_in_1965(63, 12)
add_psalms_merging_verse_1_in_1965(64, 11)
add_psalms_merging_verse_1_in_1965(65, 14)
add_psalms_merging_verse_1_in_1965(67, 8)
add_psalms_merging_verse_1_in_1965(68, 36)
add_psalms_merging_verse_1_in_1965(69, 37)
add_psalms_merging_verse_1_in_1965(70, 6)
add_psalms_merging_verse_1_in_1965(75, 11)
add_psalms_merging_verse_1_in_1965(76, 13)
add_psalms_merging_verse_1_in_1965(77, 21)
add_psalms_merging_verse_1_in_1965(80, 20)
add_psalms_merging_verse_1_in_1965(81, 17)
add_psalms_merging_verse_1_in_1965(83, 19)
add_psalms_merging_verse_1_in_1965(84, 13)
add_psalms_merging_verse_1_in_1965(85, 14)
add_psalms_merging_verse_1_in_1965(88, 19)
add_psalms_merging_verse_1_in_1965(89, 53)
add_psalms_merging_verse_1_in_1965(92, 16)
add_psalms_merging_verse_1_in_1965(102, 29)
add_psalms_merging_verse_1_in_1965(108, 14)
add_psalms_merging_verse_1_in_1965(140, 14)
add_psalms_merging_verse_1_in_1965(142, 8)

#song
l65_to_hb_merge[(('songs', 4, 16),('songs', 4, 17))] = ('songs', 4, 16)
l65_to_hb[('songs', 7, 1)] = ('songs', 6, 13)
for i in range(2, 14+1):
    l65_to_hb[('songs', 7, i)]=('songs', 7, i-1)

#zechariah
for i in range(18, 21+1):
    l65_to_hb[('zechariah', 2, i-17)]=('zechariah', 1, i)
for i in range(5, 17+1):
    l65_to_hb[('zechariah', 2, i)]=('zechariah', 2, i-4)
#found out..
l65_to_hb_merge[(('genesis', 14, 20),('genesis', 14, 21))] = ('genesis', 24, 20)
l65_to_hb[('genesis', 14, 22)]=('genesis', 14, 21)
l65_to_hb_merge[(('genesis', 14, 23), "zeme")]=(('genesis', 14, 22), ('genesis', 14, 23))


# ebreju vietturis : lv vietturis
hb_to_l65 = {v: k for k, v in l65_to_hb.items() if v[0]!= '!'}
hb_to_l65_merge = {v: k for k, v in l65_to_hb_merge.items()}
for k, v in l65_to_hb_merge.items():
    #multiple hebrews to single latvian
    if isinstance(v[1], tuple):
        for resolvedVerse in v:
            #this is case where split string is specified for single latvian verse
            if(isinstance(k[0], tuple) and isinstance(k[1], str)):
                hb_to_l65[resolvedVerse] = ("!"+k[0][0], k[0][1], k[0][2])
                l65_to_hb[k[0]] = ("!", -1, -1)
            #also never happens in current list, what was the reasoning putting else here, "just so that it is"?
            else:
                hb_to_l65[resolvedVerse] = ("!"+k[0], k[1], k[2])
                l65_to_hb[k[0]] = ("!", -1, -1)
#value is single hebrew verse. so if key 2nd is tuple not string then
    elif isinstance(k[1], tuple):
        #where to split the hebrew verse (no case actually in current list!
        if(isinstance(v[0], tuple) and isinstance(v[1], str)):
            for resolvedVerse in k:
                hb_to_l65[resolvedVerse] = ("!"+v[0][0], v[0][1], v[0][2])
                hb_to_l65[v[0]] = ("!", -2, -2)
        #single heb verse maps to multiple lvs, so put pointer mark ! (watch merges instead of direct)
        #and the rest two just placeholders so that they are not misused anywhere as misguiding references
        else:
            for resolvedVerse in k:
                l65_to_hb[resolvedVerse] = ("!"+v[0], v[1], v[2])
            #print(v[0])
            hb_to_l65[v] = ("!", -2, -2)
### false alarm, this turns out was standard case of 2 hb verses in single lv verse.
#    elif isinstance(k[1], str) and len(v) == 3:
#        #"part of the verse is one verse in hebrew". for now i will leave the latvian to hebrew map not specified, as its not used for now anyways
#        hb_to_l65[v] = ("!", -2, -2)
#        #print(v)
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! IZLAISTS PANTS 1965
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
hb_to_l65[('exodus', 1, 21)] = None

# %% [markdown]
# # split defs

# %% [markdown]
# ## small diffs fixer definition

# %%
import unicodedata
import re

# Hebrew letters that commonly get dropped at word endings by AI
HEBREW_FINAL_LETTERS = set("ךםןףץ")  # final kaf, mem, nun, pe, tsadi
HEBREW_SAMEK = "ס"
HEBREW_PE_FINAL = "ף"
HEBREW_SAMEK_STANDALONE = {"פ", "ס"}  # paragraph markers often standalone

def hebrew_char_count(s):
    """Count only base Hebrew letters, ignoring diacritics/cantillation."""
    return sum(1 for c in s if '\u05D0' <= c <= '\u05EA')

def strip_diacritics(s):
    """Remove all Hebrew diacritics, vowels, cantillation — keep base letters only."""
    return ''.join(c for c in s if '\u05D0' <= c <= '\u05EA')

def is_single_diacritic_diff(ref, json_w):
    """True if words differ only by diacritics/cantillation marks."""
    return strip_diacritics(ref) == strip_diacritics(json_w)

def is_one_char_diff(ref, json_w):
    """True if base letter sequences differ by exactly one character."""
    r = strip_diacritics(ref)
    j = strip_diacritics(json_w)
    if abs(len(r) - len(j)) > 1:
        return False
    # same length: exactly one substitution
    if len(r) == len(j):
        return sum(a != b for a, b in zip(r, j)) == 1
    # one longer: one insertion/deletion
    longer, shorter = (r, j) if len(r) > len(j) else (j, r)
    i = 0
    diffs = 0
    for c in longer:
        if i < len(shorter) and shorter[i] == c:
            i += 1
        else:
            diffs += 1
    return diffs == 1

def is_missing_final_letter(ref, json_w):
    """True if json is missing a final Hebrew letter that ref has."""
    r = strip_diacritics(ref)
    j = strip_diacritics(json_w)
    return len(r) == len(j) + 1 and r[:-1] == j and r[-1] in HEBREW_FINAL_LETTERS

def autofix_hebrew_json(file_path, verse_index, ref_hb_words, verbose=True):
    """
    Reads a verse JSON file, compares hebrew fields against ref_hb_words,
    and auto-fixes:
      1. Diacritics-only differences → replace with ref word
      2. Single base-letter difference → replace with ref word
      3. Missing final letter (samek/pe/finals) → replace with ref word
      4. Missing word (ref has more) → insert minimal JSON entry
    Writes back without reformatting (compact per-word lines preserved).
    """
    with open(file_path, "r", encoding="utf-8") as f:
        raw = f.read()

    data = json.loads(raw)
    verse_data = data[verse_index]  # index into the list
    mapping_hb_words = verse_data.get("hebrew_words", [])

    fixes = []
    ref_list = [str(ref_hb_words.iloc[j]["form"]) for j in range(len(ref_hb_words))]
    json_list = [w.get("hebrew", "") for w in mapping_hb_words]
    PARAGRAPH_MARKERS = {"ס", "פ"}

    # --- Pass 1: fix existing words where counts match ---
    if len(ref_list) == len(json_list):
        for i, (ref_w, json_w) in enumerate(zip(ref_list, json_list)):
            if ref_w == json_w:
                continue
            if (is_single_diacritic_diff(ref_w, json_w) or
                is_one_char_diff(ref_w, json_w) or
                is_missing_final_letter(ref_w, json_w)):
                if verbose:
                    print(f"  ✏️🇮🇱  [{i+1}] '{json_w}' → '{ref_w}'")
                mapping_hb_words[i]["hebrew"] = ref_w
                fixes.append(("replace", i, json_w, ref_w))
                
    # --- Pass 2: insert missing paragraph marker only ---
    elif len(ref_list) == len(json_list) + 1:
        last_ref = strip_diacritics(ref_list[-1])
        if last_ref in PARAGRAPH_MARKERS:
            if verbose:
                print(f"  ➕🇮🇱 inserting missing paragraph marker '{ref_list[-1]}'")
            mapping_hb_words.append({"hebrew": ref_list[-1], "greek": [], "latvian": []})
            fixes.append(("insert_marker", len(ref_list)-1, ref_list[-1]))
        else:
            if verbose:
                print(f"  ⚠️🇮🇱 count mismatch but last ref '{ref_list[-1]}' is not a paragraph marker — skipping")
            return False
            mapping_hb_words = new_words
            data["hebrew_words"] = mapping_hb_words
    
    if not fixes:
        return False  # nothing changed
    
        # --- Write back preserving compact format ---
        # Strategy: re-serialize only the hebrew_words array compactly,
        # then splice back into raw string to avoid full reformat
    
    def word_to_compact(w):
        heb = w.get("hebrew", "")
        greek = w.get("greek", [])
        latvian = w.get("latvian", [])
        gr_str = json.dumps(greek, ensure_ascii=False)
        lv_str = json.dumps(latvian, ensure_ascii=False)
        return f'{{ "hebrew": "{heb}", "greek": {gr_str}, "latvian": {lv_str} }}'

    compact_words = ",\n      ".join(word_to_compact(w) for w in mapping_hb_words)
    new_words_block = f"[\n      {compact_words}\n    ]"


    # write back
    def word_to_compact(w):
        heb = w.get("hebrew", "")
        greek = w.get("greek", [])
        latvian = w.get("latvian", [])
        gr_str = json.dumps(greek, ensure_ascii=False)
        lv_str = json.dumps(latvian, ensure_ascii=False)
        return f'{{ "hebrew": "{heb}", "greek": {gr_str}, "latvian": {lv_str} }}'

    # update the verse in place
    verse_data["hebrew_words"] = mapping_hb_words
    data[verse_index] = verse_data

    # reserialize each verse compactly
    verse_blocks = []
    for verse in data:
        words = verse.get("hebrew_words", [])
        compact_words = ",\n      ".join(word_to_compact(w) for w in words)
        lo_lv = json.dumps(verse.get("leftover_latvian", []), ensure_ascii=False)
        lo_gr = json.dumps(verse.get("leftover_greek", []), ensure_ascii=False)
        verse_blocks.append(
            f'  {{\n    "hebrew_words": [\n      {compact_words}\n    ],\n'
            f'    "leftover_greek": {lo_gr},\n'
            f'    "leftover_latvian": {lo_lv}\n  }}'
        )

    new_raw = "[\n" + ",\n".join(verse_blocks) + "\n]"

    with open(file_path, "w", encoding="utf-8") as f:
        f.write(new_raw)
    if verbose:
        print(f"  ✅🇮🇱 {len(fixes)} fix(es) written to {file_path}")
    return True

# %% [markdown]
# ## fixer for greek

# %%
def strip_greek_diacritics(s):
    """Remove Greek diacritics/accents, keep base letters only."""
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'  # Mn = nonspacing mark
    )

def is_greek_diacritic_diff(ref, json_w):
    """True if Greek words differ only by accents/diacritics.
    Skip single-char words where diacritic changes the word entirely."""
    stripped_ref = strip_greek_diacritics(ref)
    stripped_json = strip_greek_diacritics(json_w)
    # don't fix single-letter words — ἡ/ἢ/ἦ are different words
    if len(stripped_ref) <= 1:
        return False
    return stripped_ref == stripped_json

def autofix_greek_and_leftovers(file_path, verse_index, ref_strongs, verbose=True):
    """
    1. For each hebrew_word entry, fix Greek words that lost diacritics.
    2. Collect all Greek words from ref_strongs that are not mapped
       in any hebrew_word's greek list, and add missing ones to leftover_greek.
    ref_strongs: DataFrame with 'form' column (Greek LXX words for this verse).
    """
    if not hasattr(ref_strongs, 'iloc'):
        return False  # no strongs data for this verse

    with open(file_path, "r", encoding="utf-8") as f:
        raw = f.read()

    data = json.loads(raw)
    verse_data = data[verse_index]
    mapping_hb_words = verse_data.get("hebrew_words", [])
    leftover_greek = verse_data.get("leftover_greek", [])

    fixes = []

    # Build ref greek word list from strongs (preserving duplicates)
    ref_greek_words = [str(ref_strongs.iloc[j]["form"]) for j in range(len(ref_strongs))]

# --- Pass 1: fix diacritics in existing greek lists ---
    # Pre-build: stripped → list of unique accented forms in ref
    from collections import defaultdict
    ref_stripped_to_forms = defaultdict(set)
    for ref_gw in ref_greek_words:
        stripped = strip_greek_diacritics(ref_gw)
        if len(stripped) > 1:  # skip single-letter words
            ref_stripped_to_forms[stripped].add(ref_gw)

    for wi, word_entry in enumerate(mapping_hb_words):
        greek_list = word_entry.get("greek", [])
        for gi, gw in enumerate(greek_list):
            stripped_gw = strip_greek_diacritics(gw)
            if len(stripped_gw) <= 1:
                continue
            candidates = ref_stripped_to_forms.get(stripped_gw, set())
            # only fix if unambiguous — exactly one accented form in ref
            if len(candidates) == 1:
                ref_gw = next(iter(candidates))
                if ref_gw != gw:
                    if verbose:
                        print(f"  ✏️🇬🇷  greek [{wi+1}][{gi}] '{gw}' → '{ref_gw}'")
                    mapping_hb_words[wi]["greek"][gi] = ref_gw
                    fixes.append(("greek_replace", wi, gi, gw, ref_gw))
    # --- Pass 2: find greek words in ref not present anywhere in mapping ---
    # collect all greek words currently mapped (including leftover_greek)
    all_mapped_greek = []
    for word_entry in mapping_hb_words:
        all_mapped_greek.extend(word_entry.get("greek", []))
    all_mapped_greek.extend(leftover_greek)

    mapped_counts = Counter(w for w in all_mapped_greek)
    ref_counts = Counter(w for w in ref_greek_words)

    new_leftovers = []
    for word, count in ref_counts.items():
        missing_count = count - mapped_counts.get(word, 0)
        if missing_count > 0:
            for _ in range(missing_count):
                new_leftovers.append(word)

    if new_leftovers:
        if verbose:
            print(f"  ➕🇬🇷 greek leftovers added: {new_leftovers}")
        leftover_greek.extend(new_leftovers)
        verse_data["leftover_greek"] = leftover_greek
        fixes.append(("greek_leftover", new_leftovers))

    if not fixes:
        return False

    # update and write back
    verse_data["hebrew_words"] = mapping_hb_words
    data[verse_index] = verse_data

    def word_to_compact(w):
        heb = w.get("hebrew", "")
        greek = w.get("greek", [])
        latvian = w.get("latvian", [])
        gr_str = json.dumps(greek, ensure_ascii=False)
        lv_str = json.dumps(latvian, ensure_ascii=False)
        return f'{{ "hebrew": "{heb}", "greek": {gr_str}, "latvian": {lv_str} }}'

    verse_blocks = []
    for verse in data:
        words = verse.get("hebrew_words", [])
        compact_words = ",\n      ".join(word_to_compact(w) for w in words)
        lo_lv = json.dumps(verse.get("leftover_latvian", []), ensure_ascii=False)
        lo_gr = json.dumps(verse.get("leftover_greek", []), ensure_ascii=False)
        verse_blocks.append(
            f'  {{\n    "hebrew_words": [\n      {compact_words}\n    ],\n'
            f'    "leftover_greek": {lo_gr},\n'
            f'    "leftover_latvian": {lo_lv}\n  }}'
        )

    new_raw = "[\n" + ",\n".join(verse_blocks) + "\n]"
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(new_raw)

    if verbose:
        print(f"  ✅ greek: {len(fixes)} fix(es) written to {file_path}")
    return True

# %% [markdown]
# ## fixer for latvian

# %%
import unicodedata, re
from collections import Counter, defaultdict

LV_CHARS = "A-Za-zāēīūģķļņšžčĀĒĪŪĢĶĻŅŠŽČ"
LV_REGEX = re.compile(f"[{LV_CHARS}]+")

def _lv_tokens(text: str):
    """Return list of Latvian word-tokens from any string."""
    return LV_REGEX.findall(unicodedata.normalize("NFC", text))

def _strip_lv_diacritics(s: str) -> str:
    """
    Lower-case and strip Latvian diacritics for comparison.
    e.g. 'Ābraham' → 'abraham', 'šķēp' → 'skep'
    """
    return "".join(
        c for c in unicodedata.normalize("NFD", s.lower())
        if unicodedata.category(c) != "Mn"
    )

def autofix_latvian_and_leftovers(file_path, verse_index, ref_lv_words_raw, verbose=True):
    """
    Pass 1 – restore diacritics (ā ē ī ū š ž č ģ ķ ļ ņ) in
             hebrew_words[*]['latvian'] using l65_df canonical forms.
             Only fixes single-token entries where the match is unambiguous.
    Pass 2 – append any ref tokens not yet accounted for to leftover_latvian.
    Writes back in the same compact format as the Hebrew / Greek fixers.
    ref_lv_words_raw : list[str]  — tokens from _lv_tokens(l65_text)
    """
    if not ref_lv_words_raw:
        return False

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.loads(f.read())

    verse_data       = data[verse_index]
    mapping_hb_words = verse_data.get("hebrew_words", [])
    leftover_latvian = verse_data.get("leftover_latvian", [])

    fixes = []

    # stripped → set of canonical ref forms
    ref_stripped_to_forms = defaultdict(set)
    for rw in ref_lv_words_raw:
        ref_stripped_to_forms[_strip_lv_diacritics(rw)].add(rw)

    # ── Pass 1 : restore diacritics ─────────────────────────────────────────
    for wi, word_entry in enumerate(mapping_hb_words):
        lv_list = word_entry.get("latvian", [])
        for li, lw in enumerate(lv_list):
            tokens = _lv_tokens(lw)
            if len(tokens) != 1:       # skip phrases; too ambiguous
                continue
            stripped_lw = _strip_lv_diacritics(tokens[0])
            candidates  = ref_stripped_to_forms.get(stripped_lw, set())
            if len(candidates) == 1:   # unambiguous
                canonical = next(iter(candidates))
                if canonical != lw:
                    if verbose:
                        print(f"  ✏️🇱🇻  latvian [{wi+1}][{li}] '{lw}' → '{canonical}'")
                    mapping_hb_words[wi]["latvian"][li] = canonical
                    fixes.append(("latvian_replace", wi, li, lw, canonical))

    # ── Pass 2 : find unmapped ref tokens → leftover_latvian ────────────────
    all_mapped_lv = []
    for word_entry in mapping_hb_words:
        for item in word_entry.get("latvian", []):
            all_mapped_lv.extend(_lv_tokens(item))
    for item in leftover_latvian:
        all_mapped_lv.extend(_lv_tokens(item))

    mapped_counts = Counter(all_mapped_lv)
    ref_counts    = Counter(ref_lv_words_raw)

    new_leftovers = []
    for word, count in ref_counts.items():
        stripped_word = _strip_lv_diacritics(word)
        matched = sum(
            v for k, v in mapped_counts.items()
            if _strip_lv_diacritics(k) == stripped_word
        )
        missing_count = count - matched
        if missing_count > 0:
            # "ne-" prefix exception: ref word "nezinu" is considered
            # covered if the JSON has the stem (e.g. "zinu") mapped
            # separately alongside a mapped "ne" token.
            lw = word.lower()
            if len(lw) > 2 and lw.startswith("ne"):
                stem = word[2:]   # preserve original casing of stem
                stem_stripped = _strip_lv_diacritics(stem)
                stem_matched = sum(
                    v for k, v in mapped_counts.items()
                    if _strip_lv_diacritics(k) == stem_stripped
                )
                if stem_matched >= count:
                    continue  # "ne" + stem covers this ref word
            for _ in range(missing_count):
                new_leftovers.append(word)

    if new_leftovers:
        if verbose:
            print(f"  ➕🇱🇻 latvian leftovers added: {new_leftovers}")
        leftover_latvian.extend(new_leftovers)
        verse_data["leftover_latvian"] = leftover_latvian
        fixes.append(("latvian_leftover", new_leftovers))

    if not fixes:
        return False

    # ── write back in compact format ─────────────────────────────────────────
    verse_data["hebrew_words"] = mapping_hb_words
    data[verse_index] = verse_data

    def word_to_compact(w):
        heb     = w.get("hebrew",  "")
        greek   = w.get("greek",   [])
        latvian = w.get("latvian", [])
        gr_str = json.dumps(greek,   ensure_ascii=False)
        lv_str = json.dumps(latvian, ensure_ascii=False)
        return f'{{ "hebrew": "{heb}", "greek": {gr_str}, "latvian": {lv_str} }}'

    verse_blocks = []
    for verse in data:
        words         = verse.get("hebrew_words", [])
        compact_words = ",\n      ".join(word_to_compact(w) for w in words)
        lo_lv = json.dumps(verse.get("leftover_latvian", []), ensure_ascii=False)
        lo_gr = json.dumps(verse.get("leftover_greek",   []), ensure_ascii=False)
        verse_blocks.append(
            f'  {{\n    "hebrew_words": [\n      {compact_words}\n    ],\n'
            f'    "leftover_greek": {lo_gr},\n'
            f'    "leftover_latvian": {lo_lv}\n  }}'
        )

    new_raw = "[\n" + ",\n".join(verse_blocks) + "\n]"
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(new_raw)

    if verbose:
        print(f"  ✅🇱🇻 {len(fixes)} fix(es) written to {file_path}")
    return True

# %% [markdown]
# ## diff renderer definition

# %%
GREEN = '\033[92m'
RED_W =  '\x1b[38;5;88m\x1b[48;5;7m'
DIFF_BLUE =  '\x1b[38;5;12m\x1b[48;15;7m'
DIFF_RED =  '\x1b[38;5;196m\x1b[48;15;7m'
RESET = '\033[0m'
def diff_hebrew_vs_json(ref_hb_words, mapping_hb_words, key):
    aminlen = min(len(ref_hb_words), len(mapping_hb_words))
    if(len(ref_hb_words)!= len(mapping_hb_words)):
        print(f"❌🇮🇱 {RED_W}{key[2]} Hebrew word count mismatch at {key}:{RESET} Ref {len(ref_hb_words)} vs JSON {len(mapping_hb_words)}")


    hadDiff = False

    for j in range(aminlen):
        ref_str  = str(ref_hb_words.iloc[j]["form"])
        json_str = mapping_hb_words[j].get("hebrew", "")
        inum= int(mapping_hb_words[j].get("index", str(j+1)))

        if ref_str == json_str:
            # identical — print plain
            if hadDiff:
                print(f"  {j+1:<4} {GREEN}{ref_str}{RESET}")
        else:
            if not hadDiff:
                print(f"Δ❌Δ🇮🇱 v{RED_W}{key[2]}{RESET} wo {DIFF_RED}{j+1}{RESET} rd : {key}  Hebrew  word mismatch")
                print(f"  {'#':<4} {'ref':<30} {'json'}")
            hadDiff = True
            # diff char by char
            minlen = min(len(ref_str), len(json_str))
            s_ref = s_json = ""
            for i in range(minlen):
                if ref_str[i] == json_str[i]:
                    s_ref  += f"{GREEN}{ref_str[i]}{RESET}"
                    s_json += f"{GREEN}{json_str[i]}{RESET}"
                else:
                    s_ref  += f"{DIFF_RED}{ref_str[i]}{RESET}"
                    s_json += f"{DIFF_RED}{json_str[i]}{RESET}"
            if len(ref_str) > minlen:
                s_ref  += f"{DIFF_BLUE}{ref_str[minlen:]}{RESET}"
            if len(json_str) > minlen:
                s_json += f"{DIFF_BLUE}{json_str[minlen:]}{RESET}"
            # one word per line to avoid bidi chaos
            print(f"  {inum:<4} ref : {s_ref}")
            print(f"  {'':4} json: {s_json}")

    # surplus words
    if len(ref_hb_words) > aminlen:
        for j in range(aminlen, len(ref_hb_words)):
            form = str(ref_hb_words.iloc[j]["form"])
            print(f"  {j+1:<4} {DIFF_BLUE}ref only : {form}{RESET}")
    if len(mapping_hb_words) > aminlen:
        for j in range(aminlen, len(mapping_hb_words)):
            heb = mapping_hb_words[j].get("hebrew", "")
            print(f"  {j+1:<4} {DIFF_BLUE}json only: {heb}{RESET}")

# %%
def split_str_tokened(input_string, tokens):
    result = []
    current_string = input_string
    
    for token in tokens:
        # Atrodam pirmo marķiera parādīšanās vietu
        token_index = current_string.find(token)
        #print(token_index)
        #print(f"::str:: {current_string} \n::token::  {token}")
        # Ja marķieris netiek atrasts, pārtraucam procesu
        if token_index == -1:
            break
            
        # Sadalām virkni: 
        # pirmā daļa līdz marķiera beigām (ieskaitot pašu marķieri)
        # otrā daļa - viss, kas paliek aiz marķiera
        split_pos = token_index + len(token)
        part = current_string[:split_pos]
        current_string = current_string[split_pos:].strip()

        result.append(part)
        

    if current_string:
        result.append(current_string)
    #print(result)
    #print("-"*50)
    #print(tokens)
    return result

# %%
import pandas as pd
import time
from pathlib import Path
import json
import os
import json
import re
from collections import Counter
import unicodedata
import subprocess
import sys
DRY_RUN=1
LOG_RENUMBER_OUTPUT=0

def validate_latvian_usage(verse_text, mappings, leftover_latvian_from_verse_data):
    """
    Pārbauda, vai visi vārdi no latviešu teksta ir atrodami kartējumos.
    Izmanto specifisku latviešu burtu kopu, lai novērstu vārdu sašķelšanos.
    """
    # 1. Normalizējam tekstu uz NFC (lai 'ī' būtu viens simbols, nevis i + macron)
    ####print(verse_text)
    verse_text = unicodedata.normalize('NFC', verse_text)
    
    # Definējam latviešu burtu kopu (lielie un mazie)
    lv_chars = "A-Za-zāēīūģķļņšžčĀĒĪŪĢĶĻŅŠŽČ"
    lv_regex = f"[{lv_chars}]+"

    # 2. Tokenizējam tekstu
    text_words = re.findall(lv_regex, verse_text)
    
    # 3. Savācam visus vārdus no kartējumiem
    mapped_words = []
    
    for m in mappings:
        # Pārbaudām galvenos kartējumus
        if m.get('latvian'):
            for item in m['latvian']:
                if item and item != "-":
                    #TODO: ja ir neatzīst un atzīst orig tulkojumos vienlaikus...
                    # Arī šeit normalizējam un meklējam ar lv_regex
                    clean_item = unicodedata.normalize('NFC', item)
                    #print(re.findall(lv_regex, clean_item))
                    mapped_words.extend(re.findall(lv_regex, clean_item))
        
        if leftover_latvian_from_verse_data:
            for item in leftover_latvian_from_verse_data:
                clean_item = unicodedata.normalize('NFC', item)
                mapped_words.extend(re.findall(lv_regex, clean_item))
    
    text_counts = Counter(text_words)
    mapped_counts = Counter(mapped_words)

    missing = []
    for word, count in text_counts.items():
        if mapped_counts[word] < count:
            lw = word.lower()
            
            # Loģika priedēklim "ne-" (piemēram, 'atzīst' vs 'neatzīst')
            if len(lw) > 2 and lw.startswith("ne"):
                stem = word[2:]  # Saglabājam oriģinālo reģistru saknei
                if mapped_counts[stem] >= count:
                    continue
            
            # Pievienojam trūkstošos gadījumus
            for _ in range(count - mapped_counts[word]):
                missing.append(word)
            
    return missing
SHOW_LATVIANS=0
def split_chapter_json(book, chapter_num, hb_g, strongs_g, lv_g):
    # Path to the source chapter file: bible/genesis/1.json
    source_path = Path("bible") / book.lower() / f"{chapter_num}.json"
    
    if not source_path.exists():
        print(f"❓ Source {source_path} not found. Skipping.")
        return

    with open(source_path, "r", encoding="utf-8") as f:
        verses_list = json.load(f)
    
    dest_dir = Path("bible") / book.lower() / str(chapter_num)
    if not DRY_RUN:
        dest_dir.mkdir(parents=True, exist_ok=True)
    
    for itsverseindex, verse_data in enumerate(verses_list):
        verse_number = int(itsverseindex)+1
        key = (book, int(chapter_num), verse_number)

        # 1. Get Reference Data
        if key not in hb_g.groups:
            print(f"⚠️🇮🇱 Missing Hebrew reference data for {key}.")
            raise Exception(f"HBRW missing - no such chapter {key}")
        else:
            ref_hb = hb_g.get_group(key).sort_values("word")
            
        if key not in strongs_g.groups:
            print(f"⚠️🇬🇷 Missing STRONGS reference data for {key}.")
            ref_strongs=[]
        else:
            ref_strongs = strongs_g.get_group(key).sort_values("word")

        # 2. hebrew validation
        mapping_hb_words = verse_data.get('hebrew_words', [])
        #print(f"{key} {len(ref_hb)}, {len(mapping_hb_words)}")
        hadfxes = autofix_hebrew_json(source_path, itsverseindex, ref_hb, verbose=True)
        if(hadfxes):
            #reload
            with open(source_path, "r", encoding="utf-8") as f:
                vverses_list = json.load(f)
            verse_data = vverses_list[itsverseindex]
            mapping_hb_words = verse_data.get('hebrew_words', [])
        hadfxes_gr = autofix_greek_and_leftovers(source_path, itsverseindex, ref_strongs, verbose=True)
        if hadfxes_gr:
            with open(source_path, "r", encoding="utf-8") as f:
                vverses_list = json.load(f)
            verse_data = vverses_list[itsverseindex]
            mapping_hb_words = verse_data.get('hebrew_words', [])
        diff_hebrew_vs_json(ref_hb, mapping_hb_words, key)
            #print(mapping_hb_words)
            #continue
        l65_text=""
        if key in hb_to_l65.keys():
            kkey = hb_to_l65[key]
            if(kkey == None):
                l65_text="-"
            else:
                if not kkey[0][0]=="!":
                    l65_text=" ".join(l65_g.get_group(kkey).sort_values("word_idx")["form"].astype(str))
                else:
                    nkey = (kkey[0][1:], kkey[1], kkey[2])
                    #print("here")
                    #print(nkey)
                    for k, v in l65_to_hb_merge.items():
                        #merge will ALWAY have at least 2 items in key (either mergable verse Nr2 or splitstring Nr1)
                        if(isinstance(k[1], str) and k[0] == nkey):
                            
                            #case 1: lv verse has multiple hebrw verses in it
                            sstr = " ".join(l65_g.get_group(nkey).sort_values("word_idx")["form"].astype(str))
                            spArr = split_str_tokened(sstr, [k[i] for i in range(1, len(k))])
                            #print(spArr)
                            if(len(spArr) != len(v)):
                                raise Exception (f"could not tokenise properly!!!@ {k} to {v}")
                            for i, vsNm in enumerate(v):
                                if vsNm == key:
                                    l65_text=spArr[i]
                                    break
                            if not l65_text:
                                raise Exception (f"could not find verse part for the {key} at {k} to {v}")
                        elif(v==key):
                            #now this is inverse case of the above, l65 verses should be merged.
                            rslt = []
                            for mrg_verse in k:
                                rslt.append(" ".join(l65_g.get_group(mrg_verse).sort_values("word_idx")["form"].astype(str)))
                            l65_text = " ".join(rslt)
                            break
                    if not  l65_text:
                        raise Exception (f"key not found! {nkey} :: {key}")
        else:
            l65_text=" ".join(l65_g.get_group(key).sort_values("word_idx")["form"].astype(str))
                    # 2. Validation: Hebrew Word Count and Order

        leftover_latvian_from_verse_data = verse_data.get('leftover_latvian', [])
        # 3a. Validation: Latvian Usage (debug only)
        if SHOW_LATVIANS:
            latvian_missing = validate_latvian_usage(l65_text, mapping_hb_words, leftover_latvian_from_verse_data)
            if latvian_missing:
                print(f"⚠️🇱🇻 Latvian mapping incomplete at {key}: Missing {', '.join(latvian_missing)}")

        # 3b. Autofix: restore diacritics + write missing words to leftover_latvian
        ref_lv_tokens = _lv_tokens(l65_text)
        hadfxes_lv = autofix_latvian_and_leftovers(
            source_path, itsverseindex, ref_lv_tokens, verbose=True
        )
        if hadfxes_lv:
            with open(source_path, "r", encoding="utf-8") as f:
                vverses_list = json.load(f)
            verse_data       = vverses_list[itsverseindex]
            mapping_hb_words = verse_data.get('hebrew_words', [])

        # 4. Construct the individual verse object
        # Note: We include the 'locus' as your build_verse_object expects it
        leftover_latvian = verse_data.get("leftover_latvian", [])

        leftover_greek = verse_data.get("leftover_greek", [])
        verse_output = {
            "locus": f"{book}_{chapter_num}_{verse_number}",
            "hebrew_words": mapping_hb_words,
            "leftover_latvian": leftover_latvian,
            "leftover_greek": leftover_greek
        }

        if not DRY_RUN:
        # 5. Write to File: bible/luke/1/luke_1_1.txt
            file_name = f"{book}_{chapter_num}_{verse_number}.txt"
            with open(dest_dir / file_name, "w", encoding="utf-8") as out_f:
                json.dump(verse_output, out_f, ensure_ascii=False, indent=4)
    if not DRY_RUN:
        #run renumber
        r = subprocess.run([sys.executable, "renumber.py", f"{dest_dir}"],
            capture_output=True, 
            text=True)
        if(LOG_RENUMBER_OUTPUT):
            print("Output from renumber.py:", r.stdout)

    print(f"✅ Successfully split {source_path} into {dest_dir}")

# %%
fixthemarks = """
hb_df['form'] = (hb_df['form']
    ##.str.replace(' ׀', '', regex=False)   # space + paseq
    ##.str.replace('؟ ', '', regex=False)   # Arabic question mark + space
    #.str.replace('-- ', '', regex=False)
    #.str.replace("‪‬", "", regex=False)
    #.str.replace("-", "", regex=False)
.str.replace("־", "", regex=False) # find . -name "*.json" | xargs sed -i 's/־//g'
                 
)

# Save and reload
hb_df.to_csv("biblehub_hb_en_direct.csv", index=False)
hb_df = None
hb_df = pd.read_csv("biblehub_hb_en_direct.csv", dtype={'strong_num': str})
hb_g = hb_df.groupby(["book", "chapter", "verse"])
#"""
#[k for k in hb_to_l65.keys() if k[0][0]=="g"]

# %%
#hb_df.query(
#    "book=='genesis' & chapter==3 & verse==22 & word==21"
#)
hb_df.query(
    "book=='genesis' & chapter==29 & verse==33 & word==5"
)
# Out:
#         verse  word   form  form_en strong_num  \
# 235979     33     5  כִּֽי  because       3588
#
#                                              strong_title strong_en_title  \
# 235979  3588: 1) that, for, because, when, as though, ...            Conj
#
#        translit                           translit_title     book  chapter
# 235979      kî-  ki-: because -- Occurrence 133 of 4334.  genesis       29

# %%
hb_df[:3]
# Out:
#    verse  word        form   form_en strong_num  \
# 0      1     0  וַיֹּ֨אמֶר  And said        559
# 1      1     1     יְהוָ֜ה    Yahweh       3068
# 2      1     2      אֵלַ֗י     to me        413
#
#                                         strong_title  \
# 0  559: 1) to say, speak, utter <BR> 1a) (Qal) to...
# 1  3068: Jehovah = the existing One<BR> 1) the pr...
# 2  413: 1) to, toward, unto (of motion) <BR> 2) i...
#
#                  strong_en_title    translit  \
# 0  Conj‑w|V‑Qal‑ConsecImperf‑3ms  way·yō·mer
# 1                    N‑proper‑ms     Yah·weh
# 2                       Prep|1cs     ’ê·lay,
#
#                                      translit_title   book  chapter
# 0  vai·Yo·mer: And said -- Occurrence 1898 of 1948.  hosea        3
# 1       Yah·weh: Yahweh -- Occurrence 5792 of 6218.  hosea        3
# 2          'e·Lai,: to me -- Occurrence 415 of 446.  hosea        3

# %% [markdown]
# # do run

# %%
import os
from pathlib import Path

DRY_RUN = 0
LOG_RENUMBER_OUTPUT = 0
SHOW_LATVIANS = 0

books = [d.name for d in Path("bible").iterdir() if d.is_dir()]

for book in sorted(books):
    book_path = Path("bible") / book
    chapters = sorted(
        int(f.stem) for f in book_path.glob("*.json") if f.stem.isdigit()
    )
    if not chapters:
        continue
    print(f"\n📖 {book} ({len(chapters)} chapters)")
    for i in chapters:
        split_chapter_json(book, i, hb_g, strongs_g, l65_g)
# Out:
# 📖 1_chronicles (14 chapters)
# ✅ Successfully split bible/1_chronicles/1.json into bible/1_chronicles/1
# ✅ Successfully split bible/1_chronicles/2.json into bible/1_chronicles/2
# ✅ Successfully split bible/1_chronicles/3.json into bible/1_chronicles/3
# ✅ Successfully split bible/1_chronicles/4.json into bible/1_chronicles/4
# ✅ Successfully split bible/1_chronicles/5.json into bible/1_chronicles/5
# ✅ Successfully split bible/1_chronicles/6.json into bible/1_chronicles/6
# ✅ Successfully split bible/1_chronicles/7.json into bible/1_chronicles/7
# ✅ Successfully split bible/1_chronicles/8.json into bible/1_chronicles/8
# ✅ Successfully split bible/1_chronicles/9.json into bible/1_chronicles/9
# ✅ Successfully split bible/1_chronicles/10.json into bible/1_chronicles/10
# ✅ Successfully split bible/1_chronicles/11.json into bible/1_chronicles/11
# ✅ Successfully split bible/1_chronicles/12.json into bible/1_chronicles/12
# ✅ Successfully split bible/1_chronicles/13.json into bible/1_chronicles/13
# ✅ Successfully split bible/1_chronicles/14.json into bible/1_chronicles/14
#
# 📖 genesis (50 chapters)
# ✅ Successfully split bible/genesis/1.json into bible/genesis/1
# ✅ Successfully split bible/genesis/2.json into bible/genesis/2
# ✅ Successfully split bible/genesis/3.json into bible/genesis/3
# ✅ Successfully split bible/genesis/4.json into bible/genesis/4
# ✅ Successfully split bible/genesis/5.json into bible/genesis/5
# ✅ Successfully split bible/genesis/6.json into bible/genesis/6
# ✅ Successfully split bible/genesis/7.json into bible/genesis/7
# ✅ Successfully split bible/genesis/8.json into bible/genesis/8
# ✅ Successfully split bible/genesis/9.json into bible/genesis/9
# ✅ Successfully split bible/genesis/10.json into bible/genesis/10
# ✅ Successfully split bible/genesis/11.json into bible/genesis/11
# ✅ Successfully split bible/genesis/12.json into bible/genesis/12
# ✅ Successfully split bible/genesis/13.json into bible/genesis/13
# ✅ Successfully split bible/genesis/14.json into bible/genesis/14
# ✅ Successfully split bible/genesis/15.json into bible/genesis/15
# ✅ Successfully split bible/genesis/16.json into bible/genesis/16
# ✅ Successfully split bible/genesis/17.json into bible/genesis/17
# ✅ Successfully split bible/genesis/18.json into bible/genesis/18
# ✅ Successfully split bible/genesis/19.json into bible/genesis/19
# ✅ Successfully split bible/genesis/20.json into bible/genesis/20
# ✅ Successfully split bible/genesis/21.json into bible/genesis/21
# ✅ Successfully split bible/genesis/22.json into bible/genesis/22
# ✅ Successfully split bible/genesis/23.json into bible/genesis/23
# ✅ Successfully split bible/genesis/24.json into bible/genesis/24
# ✅ Successfully split bible/genesis/25.json into bible/genesis/25
# ✅ Successfully split bible/genesis/26.json into bible/genesis/26
# ✅ Successfully split bible/genesis/27.json into bible/genesis/27
# ✅ Successfully split bible/genesis/28.json into bible/genesis/28
# ✅ Successfully split bible/genesis/29.json into bible/genesis/29
# ✅ Successfully split bible/genesis/30.json into bible/genesis/30
# ✅ Successfully split bible/genesis/31.json into bible/genesis/31
# ✅ Successfully split bible/genesis/32.json into bible/genesis/32
# ✅ Successfully split bible/genesis/33.json into bible/genesis/33
# ✅ Successfully split bible/genesis/34.json into bible/genesis/34
# ✅ Successfully split bible/genesis/35.json into bible/genesis/35
# ✅ Successfully split bible/genesis/36.json into bible/genesis/36
# ✅ Successfully split bible/genesis/37.json into bible/genesis/37
# ✅ Successfully split bible/genesis/38.json into bible/genesis/38
# ✅ Successfully split bible/genesis/39.json into bible/genesis/39
# ✅ Successfully split bible/genesis/40.json into bible/genesis/40
# ✅ Successfully split bible/genesis/41.json into bible/genesis/41
# ✅ Successfully split bible/genesis/42.json into bible/genesis/42
# ✅ Successfully split bible/genesis/43.json into bible/genesis/43
# ✅ Successfully split bible/genesis/44.json into bible/genesis/44
# ✅ Successfully split bible/genesis/45.json into bible/genesis/45
# ✅ Successfully split bible/genesis/46.json into bible/genesis/46
# ✅ Successfully split bible/genesis/47.json into bible/genesis/47
# ✅ Successfully split bible/genesis/48.json into bible/genesis/48
# ✅ Successfully split bible/genesis/49.json into bible/genesis/49
# ✅ Successfully split bible/genesis/50.json into bible/genesis/50
#
# 📖 isaiah (66 chapters)
# ✅ Successfully split bible/isaiah/1.json into bible/isaiah/1
# ✅ Successfully split bible/isaiah/2.json into bible/isaiah/2
# ✅ Successfully split bible/isaiah/3.json into bible/isaiah/3
# ✅ Successfully split bible/isaiah/4.json into bible/isaiah/4
# ✅ Successfully split bible/isaiah/5.json into bible/isaiah/5
# ✅ Successfully split bible/isaiah/6.json into bible/isaiah/6
# ✅ Successfully split bible/isaiah/7.json into bible/isaiah/7
# ✅ Successfully split bible/isaiah/8.json into bible/isaiah/8
# ✅ Successfully split bible/isaiah/9.json into bible/isaiah/9
# ✅ Successfully split bible/isaiah/10.json into bible/isaiah/10
# ✅ Successfully split bible/isaiah/11.json into bible/isaiah/11
# ✅ Successfully split bible/isaiah/12.json into bible/isaiah/12
# ✅ Successfully split bible/isaiah/13.json into bible/isaiah/13
# ✅ Successfully split bible/isaiah/14.json into bible/isaiah/14
# ✅ Successfully split bible/isaiah/15.json into bible/isaiah/15
# ✅ Successfully split bible/isaiah/16.json into bible/isaiah/16
# ✅ Successfully split bible/isaiah/17.json into bible/isaiah/17
# ✅ Successfully split bible/isaiah/18.json into bible/isaiah/18
# ✅ Successfully split bible/isaiah/19.json into bible/isaiah/19
# ✅ Successfully split bible/isaiah/20.json into bible/isaiah/20
# ✅ Successfully split bible/isaiah/21.json into bible/isaiah/21
# ✅ Successfully split bible/isaiah/22.json into bible/isaiah/22
# ✅ Successfully split bible/isaiah/23.json into bible/isaiah/23
# ✅ Successfully split bible/isaiah/24.json into bible/isaiah/24
# ✅ Successfully split bible/isaiah/25.json into bible/isaiah/25
# ✅ Successfully split bible/isaiah/26.json into bible/isaiah/26
# ✅ Successfully split bible/isaiah/27.json into bible/isaiah/27
# ✅ Successfully split bible/isaiah/28.json into bible/isaiah/28
# ✅ Successfully split bible/isaiah/29.json into bible/isaiah/29
# ✅ Successfully split bible/isaiah/30.json into bible/isaiah/30
# ✅ Successfully split bible/isaiah/31.json into bible/isaiah/31
# ✅ Successfully split bible/isaiah/32.json into bible/isaiah/32
# ✅ Successfully split bible/isaiah/33.json into bible/isaiah/33
# ✅ Successfully split bible/isaiah/34.json into bible/isaiah/34
# ✅ Successfully split bible/isaiah/35.json into bible/isaiah/35
# ✅ Successfully split bible/isaiah/36.json into bible/isaiah/36
# ✅ Successfully split bible/isaiah/37.json into bible/isaiah/37
# ✅ Successfully split bible/isaiah/38.json into bible/isaiah/38
# ✅ Successfully split bible/isaiah/39.json into bible/isaiah/39
# ✅ Successfully split bible/isaiah/40.json into bible/isaiah/40
# ✅ Successfully split bible/isaiah/41.json into bible/isaiah/41
# ✅ Successfully split bible/isaiah/42.json into bible/isaiah/42
# ✅ Successfully split bible/isaiah/43.json into bible/isaiah/43
# ✅ Successfully split bible/isaiah/44.json into bible/isaiah/44
# ✅ Successfully split bible/isaiah/45.json into bible/isaiah/45
# ✅ Successfully split bible/isaiah/46.json into bible/isaiah/46
# ✅ Successfully split bible/isaiah/47.json into bible/isaiah/47
# ✅ Successfully split bible/isaiah/48.json into bible/isaiah/48
# ✅ Successfully split bible/isaiah/49.json into bible/isaiah/49
# ✅ Successfully split bible/isaiah/50.json into bible/isaiah/50
# ✅ Successfully split bible/isaiah/51.json into bible/isaiah/51
# ✅ Successfully split bible/isaiah/52.json into bible/isaiah/52
# ✅ Successfully split bible/isaiah/53.json into bible/isaiah/53
# ✅ Successfully split bible/isaiah/54.json into bible/isaiah/54
# ✅ Successfully split bible/isaiah/55.json into bible/isaiah/55
# ✅ Successfully split bible/isaiah/56.json into bible/isaiah/56
# ✅ Successfully split bible/isaiah/57.json into bible/isaiah/57
# ✅ Successfully split bible/isaiah/58.json into bible/isaiah/58
# ✅ Successfully split bible/isaiah/59.json into bible/isaiah/59
# ✅ Successfully split bible/isaiah/60.json into bible/isaiah/60
# ✅ Successfully split bible/isaiah/61.json into bible/isaiah/61
# ✅ Successfully split bible/isaiah/62.json into bible/isaiah/62
# ✅ Successfully split bible/isaiah/63.json into bible/isaiah/63
# ✅ Successfully split bible/isaiah/64.json into bible/isaiah/64
# ✅ Successfully split bible/isaiah/65.json into bible/isaiah/65
# ✅ Successfully split bible/isaiah/66.json into bible/isaiah/66
#
# 📖 jeremiah (52 chapters)
# ✅ Successfully split bible/jeremiah/1.json into bible/jeremiah/1
# ✅ Successfully split bible/jeremiah/2.json into bible/jeremiah/2
# ✅ Successfully split bible/jeremiah/3.json into bible/jeremiah/3
# ✅ Successfully split bible/jeremiah/4.json into bible/jeremiah/4
# ✅ Successfully split bible/jeremiah/5.json into bible/jeremiah/5
# ✅ Successfully split bible/jeremiah/6.json into bible/jeremiah/6
# ✅ Successfully split bible/jeremiah/7.json into bible/jeremiah/7
# ✅ Successfully split bible/jeremiah/8.json into bible/jeremiah/8
# ✅ Successfully split bible/jeremiah/9.json into bible/jeremiah/9
# ⚠️🇬🇷 Missing STRONGS reference data for ('jeremiah', 10, 10).
# ✅ Successfully split bible/jeremiah/10.json into bible/jeremiah/10
# ✅ Successfully split bible/jeremiah/11.json into bible/jeremiah/11
# ✅ Successfully split bible/jeremiah/12.json into bible/jeremiah/12
# ✅ Successfully split bible/jeremiah/13.json into bible/jeremiah/13
# ✅ Successfully split bible/jeremiah/14.json into bible/jeremiah/14
# ✅ Successfully split bible/jeremiah/15.json into bible/jeremiah/15
# ✅ Successfully split bible/jeremiah/16.json into bible/jeremiah/16
# ✅ Successfully split bible/jeremiah/17.json into bible/jeremiah/17
# ✅ Successfully split bible/jeremiah/18.json into bible/jeremiah/18
# ✅ Successfully split bible/jeremiah/19.json into bible/jeremiah/19
# ✅ Successfully split bible/jeremiah/20.json into bible/jeremiah/20
# ✅ Successfully split bible/jeremiah/21.json into bible/jeremiah/21
# ✅ Successfully split bible/jeremiah/22.json into bible/jeremiah/22
# ✅ Successfully split bible/jeremiah/23.json into bible/jeremiah/23
# ✅ Successfully split bible/jeremiah/24.json into bible/jeremiah/24
# ✅ Successfully split bible/jeremiah/25.json into bible/jeremiah/25
# ✅ Successfully split bible/jeremiah/26.json into bible/jeremiah/26
# ✅ Successfully split bible/jeremiah/27.json into bible/jeremiah/27
# ✅ Successfully split bible/jeremiah/28.json into bible/jeremiah/28
# ✅ Successfully split bible/jeremiah/29.json into bible/jeremiah/29
# ✅ Successfully split bible/jeremiah/30.json into bible/jeremiah/30
# ✅ Successfully split bible/jeremiah/31.json into bible/jeremiah/31
# ✅ Successfully split bible/jeremiah/32.json into bible/jeremiah/32
# ✅ Successfully split bible/jeremiah/33.json into bible/jeremiah/33
# ✅ Successfully split bible/jeremiah/34.json into bible/jeremiah/34
# ✅ Successfully split bible/jeremiah/35.json into bible/jeremiah/35
# ✅ Successfully split bible/jeremiah/36.json into bible/jeremiah/36
# ✅ Successfully split bible/jeremiah/37.json into bible/jeremiah/37
# ✅ Successfully split bible/jeremiah/38.json into bible/jeremiah/38
# ✅ Successfully split bible/jeremiah/39.json into bible/jeremiah/39
# ✅ Successfully split bible/jeremiah/40.json into bible/jeremiah/40
# ✅ Successfully split bible/jeremiah/41.json into bible/jeremiah/41
# ✅ Successfully split bible/jeremiah/42.json into bible/jeremiah/42
# ✅ Successfully split bible/jeremiah/43.json into bible/jeremiah/43
# ✅ Successfully split bible/jeremiah/44.json into bible/jeremiah/44
# ✅ Successfully split bible/jeremiah/45.json into bible/jeremiah/45
# ✅ Successfully split bible/jeremiah/46.json into bible/jeremiah/46
# ✅ Successfully split bible/jeremiah/47.json into bible/jeremiah/47
# ✅ Successfully split bible/jeremiah/48.json into bible/jeremiah/48
# ✅ Successfully split bible/jeremiah/49.json into bible/jeremiah/49
# ✅ Successfully split bible/jeremiah/50.json into bible/jeremiah/50
# ✅ Successfully split bible/jeremiah/51.json into bible/jeremiah/51
# ✅ Successfully split bible/jeremiah/52.json into bible/jeremiah/52

# %%
DRY_RUN=0
LOG_RENUMBER_OUTPUT=0
SHOW_LATVIANS=0
#split_chapter_json("genesis", len("123456789*1234567"), hb_g, strongs_g, l65_g)
#split_chapter_json("genesis", len("123456789*123456789/123456789"), hb_g, strongs_g, l65_g)
#split_chapter_json("1_chronicles", len("1234"), hb_g, strongs_g, l65_g)
#"""
#i=9+1+1+1+1+1
ii=7-6
book="jeremiah"
r=range(ii, ii+4)
for i in r:
    #split_chapter_json("genesis", i, hb_g, strongs_g, l65_g)
    #split_chapter_json("isaiah", i, hb_g, strongs_g, l65_g)
    split_chapter_json(book, i, hb_g, strongs_g, l65_g)
    #split_chapter_json("1_chronicles", i, hb_g, strongs_g, l65_g)
#split_chapter_json("genesis", len("1"), hb_g, strongs_g, l65_g)"""
# Out:
# ✅ Successfully split bible/jeremiah/1.json into bible/jeremiah/1
# ✅ Successfully split bible/jeremiah/2.json into bible/jeremiah/2
# ✅ Successfully split bible/jeremiah/3.json into bible/jeremiah/3
# ✅ Successfully split bible/jeremiah/4.json into bible/jeremiah/4
