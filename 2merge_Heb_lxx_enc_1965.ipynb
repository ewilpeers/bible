# %%
import pandas as pd
strongs_df = pd.read_csv("greek-enh-lxx-apo-OT-blb.csv", dtype={'strong_num': str})
hb_df = pd.read_csv("biblehub_hb_en_direct.csv", dtype={'strong_num': str})

# %%
hb_df[:3]
# Out:
#    verse  word        form   form_en strong_num  \
# 0      1     0  וַיֹּ֨אמֶר  And said        559
# 1      1     1     יְהוָ֜ה    Yahweh       3068
# 2      1     2      אֵלַ֗י     to me        413
#
#                                         strong_title  \
# 0  559: 1) to say, speak, utter <BR> 1a) (Qal) to...
# 1  3068: Jehovah = the existing One<BR> 1) the pr...
# 2  413: 1) to, toward, unto (of motion) <BR> 2) i...
#
#                  strong_en_title    translit  \
# 0  Conj‑w|V‑Qal‑ConsecImperf‑3ms  way·yō·mer
# 1                    N‑proper‑ms     Yah·weh
# 2                       Prep|1cs     ’ê·lay,
#
#                                      translit_title   book  chapter
# 0  vai·Yo·mer: And said -- Occurrence 1898 of 1948.  hosea        3
# 1       Yah·weh: Yahweh -- Occurrence 5792 of 6218.  hosea        3
# 2          'e·Lai,: to me -- Occurrence 415 of 446.  hosea        3

# %% [markdown]
# ## check missing strongs

# %%
void_hb_df = hb_df[
    (hb_df["strong_num"].isna()) | 
    (hb_df["strong_num"] == 0) | 
    (hb_df["strong_num"] == "")
].copy()

# %%
len(void_hb_df)
# Out:
# 0

# %% [markdown]
# ## ok, now check the books, chaps, verses to find gaps

# %%
void_hb_df = None
def prepare_grouped(strongs_df, hb_df):
    strongs_g = strongs_df.groupby(["book", "chapter", "verse"])
    hb_g = hb_df.groupby(["book", "chapter", "verse"])
    return strongs_g, hb_g
strongs_g, hb_g = prepare_grouped(strongs_df, hb_df)

# %%
keyss = sorted(hb_g.groups.keys())
for i, key in enumerate(keyss):
    b, chapter, verse = key
    strongs_verse = strongs_g.get_group(key)
    if len(strongs_verse) < 1:
        print(key)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       2 for i, key in enumerate(keyss):
#       3     b, chapter, verse = key
# ----> 4     strongs_verse = strongs_g.get_group(key)
#       5     if len(strongs_verse) < 1:
#       6         print(key)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1114, in BaseGroupBy.get_group(self, name, obj)
#    1112 inds = self._get_index(name)
#    1113 if not len(inds):
# -> 1114     raise KeyError(name)
#    1116 if obj is None:
#    1117     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: ('1_chronicles', 1, 11)

# %%
keyss = sorted(hb_g.groups.keys())
for i, key in enumerate(keyss):
    b, chapter, verse = key
    if key not in strongs_g.groups.keys():
        print(key)
# Out:
# ('1_chronicles', 1, 11)
# ('1_chronicles', 1, 12)
# ('1_chronicles', 1, 13)
# ('1_chronicles', 1, 14)
# ('1_chronicles', 1, 15)
# ('1_chronicles', 1, 16)
# ('1_chronicles', 1, 18)
# ('1_chronicles', 1, 19)
# ('1_chronicles', 1, 20)
# ('1_chronicles', 1, 21)
# ('1_chronicles', 1, 22)
# ('1_chronicles', 1, 23)
# ('1_chronicles', 16, 24)
# ('1_kings', 3, 1)
# ('1_kings', 4, 20)
# ('1_kings', 4, 21)
# ('1_kings', 4, 25)
# ('1_kings', 4, 26)
# ('1_kings', 4, 28)
# ('1_kings', 5, 17)
# ('1_kings', 6, 11)
# ('1_kings', 6, 12)
# ('1_kings', 6, 13)
# ('1_kings', 6, 14)
# ('1_kings', 6, 18)
# ('1_kings', 6, 37)
# ('1_kings', 6, 38)
# ('1_kings', 7, 22)
# ('1_kings', 7, 31)
# ('1_kings', 8, 12)
# ('1_kings', 8, 13)
# ('1_kings', 9, 15)
# ('1_kings', 9, 16)
# ('1_kings', 9, 17)
# ('1_kings', 9, 18)
# ('1_kings', 9, 19)
# ('1_kings', 9, 20)
# ('1_kings', 9, 21)
# ('1_kings', 9, 22)
# ('1_kings', 9, 23)
# ('1_kings', 9, 25)
# ('1_kings', 11, 3)
# ('1_kings', 11, 23)
# ('1_kings', 11, 24)
# ...

# %% [markdown]
# ### is reverse true? are there verses in lxx not in this hebrew?

# %%
rkeyss = sorted(strongs_g.groups.keys())
for i, key in enumerate(rkeyss):
    b, chapter, verse = key
    if key not in hb_g.groups.keys():
        print(key)

# %% [markdown]
# ### no. therefore lets augument.

# %%
enhancd_df = pd.read_csv("20260311_152938_biblehub_LXX_EXT_el_en_direct.csv")

# %%
enh_g, hhb_g = prepare_grouped(enhancd_df, hb_df)  
hhb_g = None

# %%
rrkeyss = sorted(enh_g.groups.keys())
for i, key in enumerate(rrkeyss):
    b, chapter, verse = key
    if key not in hb_g.groups.keys():
        print(key)

# %%
kkeyss = sorted(hb_g.groups.keys())
for i, key in enumerate(kkeyss):
    b, chapter, verse = key
    if key not in enh_g.groups.keys():
        print(key)
# Out:
# ('1_kings', 22, 53)
# ('esther', 4, 6)
# ('esther', 9, 5)
# ('esther', 9, 30)
# ('jeremiah', 10, 10)
# ('proverbs', 16, 2)
# ('proverbs', 16, 3)
# ('proverbs', 16, 4)
# ('proverbs', 16, 6)
# ('proverbs', 16, 7)
# ('proverbs', 16, 8)
# ('proverbs', 16, 9)
# ('proverbs', 24, 8)

# %%
nostrongs = [
    ('1_chronicles', 1, 11),
('1_chronicles', 1, 12),
('1_chronicles', 1, 13),
('1_chronicles', 1, 14),
('1_chronicles', 1, 15),
('1_chronicles', 1, 16),
('1_chronicles', 1, 18),
('1_chronicles', 1, 19),
('1_chronicles', 1, 20),
('1_chronicles', 1, 21),
('1_chronicles', 1, 22),
('1_chronicles', 1, 23),
('1_chronicles', 16, 24),
('1_kings', 3, 1),
('1_kings', 4, 20),
('1_kings', 4, 21),
('1_kings', 4, 25),
('1_kings', 4, 26),
('1_kings', 4, 28),
('1_kings', 5, 17),
('1_kings', 6, 11),
('1_kings', 6, 12),
('1_kings', 6, 13),
('1_kings', 6, 14),
('1_kings', 6, 18),
('1_kings', 6, 37),
('1_kings', 6, 38),
('1_kings', 7, 22),
('1_kings', 7, 31),
('1_kings', 8, 12),
('1_kings', 8, 13),
('1_kings', 9, 15),
('1_kings', 9, 16),
('1_kings', 9, 17),
('1_kings', 9, 18),
('1_kings', 9, 19),
('1_kings', 9, 20),
('1_kings', 9, 21),
('1_kings', 9, 22),
('1_kings', 9, 23),
('1_kings', 9, 25),
('1_kings', 11, 3),
('1_kings', 11, 23),
('1_kings', 11, 24),
('1_kings', 11, 39),
('1_kings', 12, 2),
('1_kings', 12, 17),
('1_kings', 13, 27),
('1_kings', 14, 1),
('1_kings', 14, 2),
('1_kings', 14, 3),
('1_kings', 14, 4),
('1_kings', 14, 5),
('1_kings', 14, 6),
('1_kings', 14, 7),
('1_kings', 14, 8),
('1_kings', 14, 9),
('1_kings', 14, 10),
('1_kings', 14, 11),
('1_kings', 14, 12),
('1_kings', 14, 13),
('1_kings', 14, 14),
('1_kings', 14, 15),
('1_kings', 14, 16),
('1_kings', 14, 17),
('1_kings', 14, 18),
('1_kings', 14, 19),
('1_kings', 14, 20),
('1_kings', 15, 6),
('1_kings', 15, 32),
('1_kings', 22, 46),
('1_kings', 22, 47),
('1_kings', 22, 48),
('1_kings', 22, 49),
('1_samuel', 13, 1),
('1_samuel', 17, 12),
('1_samuel', 17, 13),
('1_samuel', 17, 14),
('1_samuel', 17, 15),
('1_samuel', 17, 16),
('1_samuel', 17, 17),
('1_samuel', 17, 18),
('1_samuel', 17, 19),
('1_samuel', 17, 20),
('1_samuel', 17, 21),
('1_samuel', 17, 22),
('1_samuel', 17, 23),
('1_samuel', 17, 24),
('1_samuel', 17, 25),
('1_samuel', 17, 26),
('1_samuel', 17, 27),
('1_samuel', 17, 28),
('1_samuel', 17, 29),
('1_samuel', 17, 30),
('1_samuel', 17, 31),
('1_samuel', 17, 41),
('1_samuel', 17, 50),
('1_samuel', 17, 55),
('1_samuel', 17, 56),
('1_samuel', 17, 57),
('1_samuel', 17, 58),
('1_samuel', 18, 1),
('1_samuel', 18, 2),
('1_samuel', 18, 3),
('1_samuel', 18, 4),
('1_samuel', 18, 5),
('1_samuel', 18, 10),
('1_samuel', 18, 11),
('1_samuel', 18, 17),
('1_samuel', 18, 18),
('1_samuel', 18, 19),
('1_samuel', 18, 30),
('1_samuel', 23, 12),
('2_chronicles', 27, 8),
('deuteronomy', 23, 24),
('esther', 4, 6),
('esther', 9, 5),
('esther', 9, 30),
('exodus', 25, 6),
('exodus', 28, 23),
('exodus', 28, 24),
('exodus', 28, 25),
('exodus', 28, 26),
('exodus', 28, 27),
('exodus', 28, 28),
('exodus', 32, 9),
('exodus', 35, 8),
('exodus', 35, 15),
('exodus', 35, 17),
('exodus', 35, 18),
('exodus', 36, 10),
('exodus', 36, 11),
('exodus', 36, 12),
('exodus', 36, 13),
('exodus', 36, 14),
('exodus', 36, 15),
('exodus', 36, 16),
('exodus', 36, 17),
('exodus', 36, 18),
('exodus', 36, 19),
('exodus', 36, 20),
('exodus', 36, 21),
('exodus', 36, 22),
('exodus', 36, 23),
('exodus', 36, 24),
('exodus', 36, 25),
('exodus', 36, 26),
('exodus', 36, 27),
('exodus', 36, 28),
('exodus', 36, 29),
('exodus', 36, 30),
('exodus', 36, 31),
('exodus', 36, 32),
('exodus', 36, 33),
('exodus', 37, 4),
('exodus', 37, 11),
('exodus', 37, 12),
('exodus', 37, 14),
('exodus', 37, 20),
('exodus', 37, 22),
('exodus', 37, 24),
('exodus', 37, 25),
('exodus', 37, 26),
('exodus', 37, 27),
('exodus', 37, 28),
('exodus', 38, 2),
('exodus', 38, 5),
('exodus', 38, 6),
('exodus', 38, 7),
('exodus', 39, 35),
('exodus', 39, 39),
('exodus', 40, 7),
('exodus', 40, 11),
('exodus', 40, 28),
('exodus', 40, 31),
('exodus', 40, 32),
('ezekiel', 1, 14),
('ezekiel', 10, 14),
('ezekiel', 27, 31),
('ezekiel', 32, 19),
('ezekiel', 33, 26),
('ezekiel', 40, 30),
('genesis', 31, 51),
('genesis', 35, 21),
('isaiah', 2, 22),
('isaiah', 56, 12),
('isaiah', 64, 1),
('jeremiah', 2, 1),
('jeremiah', 7, 1),
('jeremiah', 7, 28),
('jeremiah', 8, 11),
('jeremiah', 8, 12),
('jeremiah', 10, 6),
('jeremiah', 10, 7),
('jeremiah', 10, 8),
('jeremiah', 10, 10),
('jeremiah', 11, 7),
('jeremiah', 17, 1),
('jeremiah', 17, 2),
('jeremiah', 17, 3),
('jeremiah', 17, 4),
('jeremiah', 25, 14),
('jeremiah', 27, 1),
('jeremiah', 27, 7),
('jeremiah', 27, 13),
('jeremiah', 27, 17),
('jeremiah', 27, 21),
('jeremiah', 29, 16),
('jeremiah', 29, 17),
('jeremiah', 29, 18),
('jeremiah', 29, 19),
('jeremiah', 29, 20),
('jeremiah', 30, 10),
('jeremiah', 30, 11),
('jeremiah', 30, 15),
('jeremiah', 30, 22),
('jeremiah', 33, 14),
('jeremiah', 33, 15),
('jeremiah', 33, 16),
('jeremiah', 33, 17),
('jeremiah', 33, 18),
('jeremiah', 33, 19),
('jeremiah', 33, 20),
('jeremiah', 33, 21),
('jeremiah', 33, 22),
('jeremiah', 33, 23),
('jeremiah', 33, 24),
('jeremiah', 33, 25),
('jeremiah', 33, 26),
('jeremiah', 39, 4),
('jeremiah', 39, 5),
('jeremiah', 39, 6),
('jeremiah', 39, 7),
('jeremiah', 39, 8),
('jeremiah', 39, 9),
('jeremiah', 39, 10),
('jeremiah', 39, 11),
('jeremiah', 39, 12),
('jeremiah', 39, 13),
('jeremiah', 46, 1),
('jeremiah', 46, 26),
('jeremiah', 48, 45),
('jeremiah', 48, 46),
('jeremiah', 48, 47),
('jeremiah', 49, 6),
('jeremiah', 51, 45),
('jeremiah', 51, 46),
('jeremiah', 51, 47),
('jeremiah', 51, 48),
('jeremiah', 52, 2),
('jeremiah', 52, 3),
('jeremiah', 52, 15),
('jeremiah', 52, 28),
('jeremiah', 52, 29),
('jeremiah', 52, 30),
('job', 23, 14),
('joshua', 6, 4),
('joshua', 8, 13),
('joshua', 8, 26),
('joshua', 10, 15),
('joshua', 10, 43),
('joshua', 13, 33),
('joshua', 20, 4),
('joshua', 20, 5),
('joshua', 20, 6),
('lamentations', 3, 22),
('lamentations', 3, 23),
('lamentations', 3, 24),
('lamentations', 3, 29),
('nehemiah', 3, 7),
('nehemiah', 4, 6),
('nehemiah', 11, 16),
('nehemiah', 11, 20),
('nehemiah', 11, 21),
('nehemiah', 11, 28),
('nehemiah', 11, 29),
('nehemiah', 11, 32),
('nehemiah', 11, 33),
('nehemiah', 11, 34),
('nehemiah', 11, 35),
('nehemiah', 12, 4),
('nehemiah', 12, 5),
('nehemiah', 12, 6),
('proverbs', 4, 7),
('proverbs', 8, 33),
('proverbs', 11, 4),
('proverbs', 15, 31),
('proverbs', 16, 1),
('proverbs', 16, 3),
('proverbs', 16, 6),
('proverbs', 16, 9),
('proverbs', 18, 23),
('proverbs', 18, 24),
('proverbs', 19, 1),
('proverbs', 19, 2),
('proverbs', 20, 14),
('proverbs', 20, 15),
('proverbs', 20, 16),
('proverbs', 20, 17),
('proverbs', 20, 18),
('proverbs', 20, 19),
('proverbs', 21, 5),
('proverbs', 22, 6),
('proverbs', 23, 23),
('psalms', 13, 6),
('psalms', 116, 14)
]
noench = [
('1_kings', 22, 53),
('esther', 4, 6),
('esther', 9, 5),
('esther', 9, 30),
('jeremiah', 10, 10),
('proverbs', 16, 2),
('proverbs', 16, 3),
('proverbs', 16, 4),
('proverbs', 16, 6),
('proverbs', 16, 7),
('proverbs', 16, 8),
('proverbs', 16, 9),
('proverbs', 24, 8)
]

print(set(noench) - set(nostrongs))
# Out:
# {('proverbs', 16, 7), ('proverbs', 16, 4), ('proverbs', 16, 2), ('proverbs', 24, 8), ('1_kings', 22, 53), ('proverbs', 16, 8)}

# %%
#for i in nostrongs:
#    if i not in enh_g.groups.keys():
#        continue
#    else:
#        strongs_df[i] = enh_g.groups[i]

# %%
enh_g.head()
# Out:
#         verse  word_idx           form        form_en strong_num  \
# 0           1         0            και            And       2532
# 1           1         1    είπε κύριος  the lord said  2036|2962
# 2           1         2           προς             to       4314
# 3           1         3             με            me,       1473
# 4           1         4  έτι πορεύθητι   You go again  2089|4198
# ...       ...       ...            ...            ...        ...
# 450250     36         0            και            And       2532
# 450251     36         1         έδωκαν      they gave       1325
# 450252     36         2             το            the       3588
# 450253     36         3        νόμισμα        mandate       3546
# 450254     36         4            του         of the       3588
#
#                                              strong_title   book  chapter
# 0                                         and, even, also  hosea        3
# ...

# %%
strongs_df[:3]
# Out:
#        form strong_num strong_en_title     book  chapter  verse  word  \
# 0        ἐν       1722            Prep  genesis        1      1     0
# 1      ἀρχῇ        746           N-DSF  genesis        1      1     1
# 2  ἐποίησεν       4160        V-AAI-3S  genesis        1      1     2
#
#   is_patched
# 0        NaN
# 1        NaN
# 2        NaN

# %%
new_rows_list = []

for i in nostrongs:
    if i not in enh_g.groups.keys():
        continue
    else:

    #if i in enh_g.groups:
        # Iegūstam DataFrame grupu šai atslēgai
        group_df = enh_g.get_group(i)
        new_rows_list.append(group_df)

# 2. Ja saraksts nav tukšs, apvienojam visu vienā DataFrame
if new_rows_list:
    new_data = pd.concat(new_rows_list, ignore_index=True)
    
    # 3. Pievienojam klāt tavam oriģinālajam DataFrame
#strongs_df = pd.concat([strongs_df, new_data], ignore_index=True)

#print(f"Pievienotas {len(new_data)} jaunas rindas.")
new_data.head()
# Out:
#    verse  word_idx      form     form_en strong_num              strong_title  \
# 0     11         0       και         NaN       2532           and, even, also
# 1     11         1   Μεσραϊμ     Mizraim        NaN                       NaN
# 2     11         2  εγέννησε  procreated       1080  to beget, to bring forth
# 3     11         3      τους         the       3588                       the
# 4     11         4  Λουδιείμ      Ludim,        NaN                       NaN
#
#            book  chapter
# 0  1_chronicles        1
# 1  1_chronicles        1
# 2  1_chronicles        1
# 3  1_chronicles        1
# 4  1_chronicles        1

# %%
len(new_data)
# Out:
# 5798

# %%
new_data = new_data.rename(columns={
    'strong_title': 'strong_en_title',
    'word_idx': 'word'
})

# %%
new_data.head()
# Out:
#    verse  word      form     form_en strong_num           strong_en_title  \
# 0     11     0       και         NaN       2532           and, even, also
# 1     11     1   Μεσραϊμ     Mizraim        NaN                       NaN
# 2     11     2  εγέννησε  procreated       1080  to beget, to bring forth
# 3     11     3      τους         the       3588                       the
# 4     11     4  Λουδιείμ      Ludim,        NaN                       NaN
#
#            book  chapter
# 0  1_chronicles        1
# 1  1_chronicles        1
# 2  1_chronicles        1
# 3  1_chronicles        1
# 4  1_chronicles        1

# %%
nstrongs_df = pd.concat([strongs_df, new_data], ignore_index=True)

# %%
nstrongs_df.head()
# Out:
#        form strong_num strong_en_title     book  chapter  verse  word  \
# 0        ἐν       1722            Prep  genesis        1      1     0
# 1      ἀρχῇ        746           N-DSF  genesis        1      1     1
# 2  ἐποίησεν       4160        V-AAI-3S  genesis        1      1     2
# 3         ὁ       3588         Art-NSM  genesis        1      1     3
# 4      θεὸς       2316           N-NSM  genesis        1      1     4
#
#   is_patched form_en
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN

# %%
nstrongs_df.query(
    "book=='1_chronicles' and chapter==1 and verse==11"
).head()
# Out:
#             form strong_num           strong_en_title          book  chapter  \
# 473529       και       2532           and, even, also  1_chronicles        1
# 473530   Μεσραϊμ        NaN                       NaN  1_chronicles        1
# 473531  εγέννησε       1080  to beget, to bring forth  1_chronicles        1
# 473532      τους       3588                       the  1_chronicles        1
# 473533  Λουδιείμ        NaN                       NaN  1_chronicles        1
#
#         verse  word is_patched     form_en
# 473529     11     0        NaN         NaN
# 473530     11     1        NaN     Mizraim
# 473531     11     2        NaN  procreated
# 473532     11     3        NaN         the
# 473533     11     4        NaN      Ludim,

# %%
new_data = new_data.rename(columns={
    'strong_en_title': 'strong_title',
})

# %%
nstrongs_df = pd.concat([strongs_df, new_data], ignore_index=True)

# %%
nstrongs_df.head()
# Out:
#        form strong_num strong_en_title     book  chapter  verse  word  \
# 0        ἐν       1722            Prep  genesis        1      1     0
# 1      ἀρχῇ        746           N-DSF  genesis        1      1     1
# 2  ἐποίησεν       4160        V-AAI-3S  genesis        1      1     2
# 3         ὁ       3588         Art-NSM  genesis        1      1     3
# 4      θεὸς       2316           N-NSM  genesis        1      1     4
#
#   is_patched form_en strong_title
# 0        NaN     NaN          NaN
# 1        NaN     NaN          NaN
# 2        NaN     NaN          NaN
# 3        NaN     NaN          NaN
# 4        NaN     NaN          NaN

# %%
nstrongs_df.query(
    "book=='1_chronicles' and chapter==1 and verse==11"
).head()
# Out:
#             form strong_num strong_en_title          book  chapter  verse  \
# 473529       και       2532             NaN  1_chronicles        1     11
# 473530   Μεσραϊμ        NaN             NaN  1_chronicles        1     11
# 473531  εγέννησε       1080             NaN  1_chronicles        1     11
# 473532      τους       3588             NaN  1_chronicles        1     11
# 473533  Λουδιείμ        NaN             NaN  1_chronicles        1     11
#
#         word is_patched     form_en              strong_title
# 473529     0        NaN         NaN           and, even, also
# 473530     1        NaN     Mizraim                       NaN
# 473531     2        NaN  procreated  to beget, to bring forth
# 473532     3        NaN         the                       the
# 473533     4        NaN      Ludim,                       NaN

# %%
nstrongs_df.to_csv(
    "greek-enh-lxx-apo-OT-blb.csv",
    #columns=[col for col in save_columns if col in strongs_df.columns], # Drošībai pārbaudām vai eksistē
    index=False,
    encoding='utf-8',
    quoting=1,  # csv.QUOTE_ALL - ieliek visas vērtības pēdiņās
    escapechar='\\'
)

# %% [markdown]
# ## now the same against Latvian 1965 first
